# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfLoad = pd.read_csv("https://raw.githubusercontent.com/hanwoolJeong/lectureUniv/main/testData_H_vs_W.txt", sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jeong\AppData\Local\Temp\ipykernel_1984\4048393448.py:1: SyntaxWarning: invalid escape sequence '\s'
#   dfLoad = pd.read_csv("https://raw.githubusercontent.com/hanwoolJeong/lectureUniv/main/testData_H_vs_W.txt", sep="\s+")

# %%
xHeight = dfLoad.Height
yWeight = dfLoad.Weight

# %%
plt.plot(xHeight, yWeight, ".r")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/hanwoolJeong/lectureUniv/main/testData_LinearRegression.txt", sep="\s+")
xxRaw = np.array(df.values[:,0])
yyRaw = np.array(df.values[:,1])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jeong\AppData\Local\Temp\ipykernel_1984\974801146.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("https://raw.githubusercontent.com/hanwoolJeong/lectureUniv/main/testData_LinearRegression.txt", sep="\s+")

# %% [markdown]
# $$ \hat{W} = (X^T X)^{-1} X^T Y $$

# %%
N = len(xxRaw)
xx_bias = np.c_[np.ones([100, 1]), xxRaw]
yy = yyRaw.reshape(-1, 1)

wOLS = np.linalg.inv(xx_bias.T.dot(xx_bias)).dot(xx_bias.T).dot(yy)
x_sample = np.linspace(0, 2.0, 101)
x_sample_bias = np.c_[np.ones([101, 1]), x_sample]
y_pred = wOLS.T.dot(x_sample_bias.T)
x_sample_row = x_sample.reshape(1, 101)
plt.plot(xxRaw, yyRaw, "r.")
plt.plot(x_sample_row, y_pred, "b.-")
plt.show()

# %% [markdown]
# ### Batch Gradient Descent
# $$
# w_{\text{next}} = w_{\text{present}} - \eta \nabla \text{MSE}
# $$

# %%
eta = 0.1 # learning rate
n_iterations = 1000
wGD = np.zeros([2,1]) # initialized to 0

for iteration in range(n_iterations):
    gradients = -(2/N) * (xx_bias.T.dot(yy - xx_bias.dot(wGD)))
    wGD = wGD - eta * gradients

# %%
print(wOLS)
print()
print(wGD)
# Out:
# [[3.8085273 ]
#  [3.34024009]]
#
# [[3.8085273 ]
#  [3.34024009]]

# %% [markdown]
# **MLE를 이용한 최적의 W와 Gradient Descent를 이용해 구한 W가 비슷하다.**
